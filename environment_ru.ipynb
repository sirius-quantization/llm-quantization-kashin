# %%
import torch
gpu_memory_bytes = torch.cuda.get_device_properties(0).total_memory
gpu_memory_gb = round(gpu_memory_bytes / (2**30))

# %%
gpu_memory_gb

# %%
print("kek")
# Out:
# kek

# %%
print("kek")
# Out:
# kek

# %%
! nvidia-smi
# Out:
# Mon Oct  7 13:08:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.06             Driver Version: 535.183.06   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  | 00000000:8C:00.0 Off |                    0 |
# | N/A   31C    P0              77W / 500W |      9MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# ...

# %% [markdown]
# <a id='section-id0'></a>
# <h1>Настройка рабочей среды DataSphere</h1>
#
# 1. [Установить библиотек и изменить версии установленных библиотек.](#section-id1)
# 2. [Настроить окружение с помощью Docker.](#section-id2)
# 2. [Узнать о DataSphere больше.](#section-id3)

# %% [markdown]
# <a id='section-id1'></a>
# ## 1. Установить библиотеки и изменить версии установленных библиотек
#
# DataSphere — это среда разработки, готовая к использованию. На виртуальной машине уже установлена среда разработки JupyterLab и пакеты для анализа данных и машинного обучения (TensorFlow, Keras, NumPy и другие) — вы можете сразу начать их использовать. Полный список предустановленных пакетов можно посмотреть <a href="https://cloud.yandex.ru/docs/datasphere/concepts/preinstalled-packages"> в документации</a> или проверить с помощью команды `%pip list`.

# %%
# %pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiobotocore                      2.1.2
# aiohttp                          3.8.5
# aiohttp-retry                    2.8.3
# aioitertools                     0.11.0
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.2.1
# altair                           4.2.2
# amqp                             5.1.1
# antlr4-python3-runtime           4.9.3
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      21.3.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.0
# arviz                            0.15.1
# astropy                          5.2.2
# astunparse                       1.6.3
# async-timeout                    4.0.2
# asyncssh                         2.13.2
# ...

# %% [markdown]
# Если какого-то пакета вам не хватает, вы можете установить его прямо из ноутбука с помощью пакетного менеджера `%pip`. В DataSphere работают стандартные опции команды `%pip`. Вы можете проверить, какая версия библиотеки установлена, и установить более раннюю, более позднюю версию или самую свежую версию библиотеки.

# %%
# Вот так мы установим самую свежую версию нужной библиотеки
# %pip install fasttext
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for fasttext (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [89 lines of output]
#       /kernel/lib/python3.10/site-packages/setuptools/dist.py:771: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/fasttext
#       copying python/fasttext_module/fasttext/__init__.py -> build/lib.linux-x86_64-cpython-310/fasttext
#       copying python/fasttext_module/fasttext/FastText.py -> build/lib.linux-x86_64-cpython-310/fasttext
# ...

# %%
# Так можно установить конкретную нужную версию билиотеки
# %pip install fasttext==0.9.1

# %%
# А так — обновить версию уже установленного пакета
# %pip install --upgrade fasttext

# %% [markdown]
# После установки пакетов через pip не забудьте рестартовать Kernel: в верхнем меню выберите **Kernel -> Restart kernel**.

# %% [markdown]
# <a id='section-id2'></a>
#
# ## 2. Настроить окружение с помощью Docker
#
# При необходимости в DataSphere можно собрать свой Docker-образ с набором необходимых библиотек. Созданный образ хранится в репозитории Docker-образов в проекте, и может быть выбран в качестве основного для проекта. В этом случае он будет использоваться при запуске кода во всех ноутбуках проекта. [Инструкция по работе с Docker образами](https://cloud.yandex.ru/docs/datasphere/operations/user-images).

# %% [markdown]
# <a id='section-id3'></a>
#
# ## 3. Узнать о DataSphere больше
# У нас есть подробная [документация](https://cloud.yandex.ru/docs/datasphere/).
#
# **Видео и демо**
#
# - Презентация новой версии DataSphere с обновленным интерфейсом: [Yandex DataSphere: новый UI и возможности командной ML-разработки
# ](https://www.youtube.com/watch?v=xzEW5g7WVd4&themeRefresh=1).
#
# - Организация командной работы с помощью сообщества и проектов: [Возможности DataSphere для распределённых ML-команд
# ](https://www.youtube.com/watch?v=xM0qdz5wJdE)
#
# **Проекты, реализованные в DataSphere**
#
# - Экономониторинг Байкала для прогнозирования состояния озера, влияния климатических изменений на его экосистему, а также оценки рыбозапаса: [О проекте](https://cloud.yandex.ru/special/baikal/), [Habr](https://habr.com/ru/companies/yandex/articles/689592/), [GitHub](https://github.com/baikal-zooplankton)
#
# - Прогнозирование природной аномалии Эль-Ниньо в Тихом океане: [О проекте](https://cloud.yandex.ru/blog/posts/2023/04/el-nino)
#
# У DataSphere есть <a href="https://t.me/yandex_datasphere"> чат сообщества в Телеграм</a>, присоединяйтесь!
